# %%
# %matplotlib inline
import numpy as np
import matplotlib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import stats
sns.set(style="whitegrid", color_codes=True)
plt.rcParams['figure.figsize'] = (12, 12)

# %%
spad = np.array([53.1,9.05,72.91,12,80.49,33.27,71.96,11.18,60.01,5.61,69.36,15.8,72.51,12.42,67.5,21.48,60.36,26.91,59.13,3.14,79.43,18.28,75.5,12.25,63.47,27.91,76.83,23.55,71.02,13.4])
wp = np.array([-6.37,-10.36,-5.38,-15.39,-5.48,-11.74,-5.48,-12.12,-5.34,-13.14,-5.98,-14.67,-5.19,-11.21,-6.23,-9.27,-7.13,-11.51,-5.94,-14.18,-6.24,-11.59,-6.39,-12.29,-6.46,-10.49,-6.81,-13.42,-5.34,-10.67])

# %%
stats.pearsonr(spad, wp)
# Out:
# (0.91702351723766495, 1.0753721957986095e-12)

# %%
fig = plt.figure()
plt.scatter(spad, wp)
fig.suptitle("Chlorophyll and Water Potential")
plt.xlabel("Chlorophyll")
plt.ylabel("Water Potential")
