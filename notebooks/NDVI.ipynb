# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid", color_codes=True)
plt.rcParams['figure.figsize'] = (12, 6)

# %%
df = pd.read_csv("../data/2016-11-17_avg_ndvi.csv", header=None)

# %%
df.describe()
# Out:
#                0
# count  35.000000
# mean    0.810871
# std     0.066721
# min     0.631547
# 25%     0.804237
# 50%     0.829725
# 75%     0.857493
# max     0.880002

# %%
ax = df.plot(kind="bar", legend=None, title="NDVI 11/17", color="#3399DD")
for container in ax.containers:
    plt.setp(container, width=0.7)
ax.set_xlabel("Lettuce Plant")
ax.set_ylabel("NDVI")
plt.tight_layout()

# %%
ax = df.plot(kind="hist", bins=14, color="#3399DD", legend=False)
ax.set_xlabel("NDVI")
